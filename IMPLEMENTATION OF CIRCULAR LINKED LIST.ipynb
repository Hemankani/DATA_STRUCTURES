# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemankani/DATA_STRUCTURES/blob/main/IMPLEMENTATION%20OF%20CIRCULAR%20LINKED%20LIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# CREATION

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class CreateList:
    def __init__(self):
        self.head = Node(None)
        self.tail = Node(None)
        self.head.next = self.tail
        self.tail.next = self.head

    def add(self, data):
        newNode = Node(data)
        if self.head.data is None:
            self.head = newNode
            self.tail = newNode
            newNode.next = self.head
        else:
            self.tail.next = newNode
            self.tail = newNode
            self.tail.next = self.head

    def deleteEnd(self):
        if self.head.data is None: # List is empty (initial state)
            print("List is empty, cannot delete.")
            return

        if self.head == self.tail: # Only one node (e.g., after add(1))
            self.head = Node(None)
            self.tail = Node(None)
            self.head.next = self.tail
            self.tail.next = self.head
            return

        current = self.head
        # Find the node before the current tail
        while current.next != self.tail:
            current = current.next

        # current is now the second to last node
        current.next = self.head # This node now points to the head
        self.tail = current # This node becomes the new tail

    def display(self):
        current = self.head
        # Check if the list is empty based on the head node's data being None
        # and ensure it's not just the initial dummy head/tail setup
        if self.head.data is None and self.head == self.tail:
            print("List is empty")
            return
        else:
            print("Nodes of the circular linked list: ", end="")
            print(current.data, end=" ")
            current = current.next
            while current != self.head:
                print(current.data, end=" ")
                current = current.next
            print() # Print a newline at the end

# Execution block
cl = CreateList()
cl.add(1)
cl.add(2)
cl.add(3)
cl.add(4)
cl.display()
# Out:
# Nodes of the circular linked list: 1 2 3 4

# %% [markdown]
# INSERTION

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.last = None

    def addToEmpty(self, data):
        if self.last is not None:
            return self.last
        temp = Node(data)
        self.last = temp
        self.last.next = self.last
        return self.last

    def addBegin(self, data):
        if self.last is None:
            return self.addToEmpty(data)
        temp = Node(data)
        temp.next = self.last.next
        self.last.next = temp
        return self.last

    def addEnd(self, data):
        if self.last is None:
            return self.addToEmpty(data)
        temp = Node(data)
        temp.next = self.last.next
        self.last.next = temp
        self.last = temp
        return self.last

    def addAfter(self, data, item):
        if self.last is None:
            print("List is empty, cannot add after an item")
            return None

        p = self.last.next  # Start from the first node
        found_item = False
        while True:
            if p.data == item:
                temp = Node(data)
                temp.next = p.next
                p.next = temp
                if p == self.last:  # If item was the last node, new node becomes the new last
                    self.last = temp
                found_item = True
                break  # Item found and inserted
            p = p.next
            if p == self.last.next:  # Traversed the whole list and didn't find the item
                break

        if not found_item:
            print(item, "not present in the list")
        return self.last

    def traverse(self):
        if self.last is None:
            print("List is empty")
            return

        temp = self.last.next  # Start from the first node
        while True:
            print(temp.data, end=" ")
            temp = temp.next
            if temp == self.last.next:  # Stop when we loop back to the first node
                break
        print()  # Add a newline for better formatting

if __name__ == '__main__':
    llist = CircularLinkedList()

    last = llist.addToEmpty(6)
    last = llist.addBegin(4)
    last = llist.addBegin(2)
    last = llist.addEnd(8)

    last = llist.addEnd(12)
    last = llist.addAfter(10, 8)

    llist.traverse()
# Out:
# 2 4 6 8 10 12

# %% [markdown]
# DELETION

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class CreateList:
    def __init__(self):
        self.head = None
        self.tail = None

    def add(self, data):
        newNode = Node(data)
        if self.head is None:
            self.head = newNode
            self.tail = newNode
            newNode.next = self.head  # Points to itself for a single-node circular list
        else:
            self.tail.next = newNode
            self.tail = newNode
            self.tail.next = self.head

    def deleteEnd(self):
        if self.head is None:
            # print("List is empty, cannot delete.") # Removed comment for cleaner output
            return

        if self.head == self.tail:  # Only one node
            self.head = None
            self.tail = None
            return

        current = self.head
        # Find the node before the current tail
        while current.next != self.tail:
            current = current.next

        # current is now the second to last node
        current.next = self.head  # This node now points to the head
        self.tail = current      # This node becomes the new tail

    def display(self):
        if self.head is None:
            print("List is empty")
            return

        current = self.head
        while True:
            print(current.data, end=" ")
            current = current.next
            if current == self.head:
                break
        print()  # Add a newline for better formatting

# Execution block
cl = CreateList()
cl.add(1)
cl.add(2)
cl.add(3)
cl.add(4)

print("Original List:")
cl.display()

while cl.head is not None:
    cl.deleteEnd()
    print("Updated List:")
    cl.display()
# Out:
# Original List:
# 1 2 3 4
# Updated List:
# 1 2 3
# Updated List:
# 1 2
# Updated List:
# 1
# Updated List:
# List is empty

# %% [markdown]
# TRAVERSAL

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class CircularLinkedList:
    def __init__(self):
        self.head = None

    def push(self, data):
        ptr1 = Node(data)
        ptr1.next = self.head

        if self.head is not None:
            temp = self.head
            while temp.next != self.head:
                temp = temp.next
            temp.next = ptr1
        else:
            # If list was empty, new node points to itself
            ptr1.next = ptr1

        self.head = ptr1

    def printList(self):
        if self.head is None:
            print("List is empty")
            return

        temp = self.head
        while True:
            print(temp.data, end=" ")
            temp = temp.next
            if temp == self.head:
                break
        print() # For newline

cllist = CircularLinkedList()
cllist.push(12)
cllist.push(56)
cllist.push(2)
cllist.push(11)
print("Contents of circular Linked List")
cllist.printList()
# Out:
# Contents of circular Linked List
# 11 2 56 12
